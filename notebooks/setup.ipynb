# %%
import sys
from pathlib import Path
import re

# Subir un nivel desde notebooks/ y entrar a src/
sys.path.append(str(Path('..') / 'src'))

from config import CH #conexión con ClickHouse
from utils import execute_sql_file  #

# %%
execute_sql_file('../sql/bronze-layer-ddl.sql', CH)
# Out:
# Sentencias encontradas: 16
# [1/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_actor ( actor_id Int32...
# [2/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_address ( address_id I...
# [3/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_category ( category_id...
# [4/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_city ( city_id Int32, ...
# [5/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_country ( country_id I...
# [6/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_customer ( customer_id...
# [7/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_film ( film_id Int32, ...
# [8/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_film_actor ( actor_id ...
# [9/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_film_category ( film_i...
# [10/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_film_text ( film_id In...
# [11/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_inventory ( inventory_...
# [12/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_language ( language_id...
# [13/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_payment ( payment_id I...
# [14/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_rental ( rental_id Int...
# [15/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_staff ( staff_id Int32...
# [16/16] ✓ CREATE TABLE IF NOT EXISTS bronze.raw_store ( store_id Int32...
#
# ✓ 16 sentencias ejecutadas desde ../sql/bronze-layer-ddl.sql
